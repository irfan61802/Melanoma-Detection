# %%
import os,glob
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import cv2

from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import Callback,EarlyStopping
from sklearn import metrics
#for ResNet50
from tensorflow.keras.applications import ResNet50, MobileNetV2
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.metrics import classification_report
#for Xception
from tf_explain.core.activations import ExtractActivations
from tensorflow.keras.applications.xception import decode_predictions

# %%
#get file path of training data 
file_path='MelanomaImages'
#get classes from folder names for benign and malignant
name_class=os.listdir(file_path)
name_class
# Out:
# ['benign', 'malignant']

# %%
#get and store filepaths of all images
filepaths=list(glob.glob(file_path+'/**/*.*'))
#store the labels according to folder
labels=list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

# %%
#store data as series
filepath= pd.Series(filepaths, name='Filepath').astype(str)
labels=pd.Series(labels, name='Label')
data=pd.concat([filepath, labels],axis=1)
data=data.sample(frac=1).reset_index(drop=True)
data.head(5)
# Out:
#                                     Filepath      Label
# 0     MelanomaImages\benign\ISIC_6342190.JPG     benign
# 1  MelanomaImages\malignant\ISIC_0059547.JPG  malignant
# 2  MelanomaImages\malignant\ISIC_0060962.JPG  malignant
# 3     MelanomaImages\benign\ISIC_3410530.JPG     benign
# 4     MelanomaImages\benign\ISIC_1087923.JPG     benign

# %%
#check count of each class
counts=data.Label.value_counts()
sb.barplot(x=counts.index, y=counts)
plt.xlabel('Type')
plt.xticks(rotation=90)
# Out:
# (array([0, 1]), [Text(0, 0, 'benign'), Text(1, 0, 'malignant')])

# %%
#train test split for validation with 0.25 
train, test= train_test_split(data, test_size=0.25, random_state=53)

# %%
#some example data
fig, axes= plt.subplots(nrows=5, ncols=3, figsize=(10,8), subplot_kw={'xticks':[],'yticks':[]})
for i, ax in enumerate(axes.flat):
    img=plt.imread(data.Filepath[i])
    ax.imshow(cv2.resize(img, (224,224)))
    ax.set_title(data.Label[i])
    plt.tight_layout()
plt.show()

# %%
#apply preprocessing: normalizing, reshaping, augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train_gen = train_datagen.flow_from_dataframe(
    dataframe=train,
    x_col='Filepath',
    y_col='Label',
    target_size=(224,224),
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42
)
valid_gen = train_datagen.flow_from_dataframe(
    dataframe=test,
    x_col='Filepath',
    y_col='Label',
    target_size=(224,224),
    class_mode='categorical',
    batch_size=32,
    shuffle=False,
    seed=42
)
test_gen = test_datagen.flow_from_dataframe(
    dataframe=test,
    x_col='Filepath',
    y_col='Label',
    target_size=(224,224),
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 5700 validated image filenames belonging to 2 classes.
# Found 1900 validated image filenames belonging to 2 classes.
# Found 1900 validated image filenames belonging to 2 classes.

# %%
pretrained_model= ResNet50(
    input_shape=(224,224,3),
    include_top=False,
    weights='imagenet',
    pooling='avg'

)
pretrained_model.traindable= False

# %%
#add dense and softmax layers
inputs = pretrained_model.input

x=Dense(128,activation='relu')(pretrained_model.output)
x=Dense(128,activation='relu')(x)

outputs=Dense(2,activation='softmax')(x)

model=Model(inputs=inputs, outputs=outputs)

# %%
model.compile(
    optimizer='adam',  #can test different ones
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
#early stopping function if no improvement for more than 2 epochs
my_callbacks = [EarlyStopping(monitor='val_accuracy',
                              min_delta=0,
                              patience=2,
                              mode='max')]

# %%
history= model.fit(
    train_gen,
    validation_data=valid_gen,
    epochs=10
)
# Out:
# Epoch 1/10
# 179/179 [==============================] - 1700s 9s/step - loss: 0.4964 - accuracy: 0.7902 - val_loss: 1.2789 - val_accuracy: 0.6958
# Epoch 2/10
# 179/179 [==============================] - 1706s 10s/step - loss: 0.4035 - accuracy: 0.8337 - val_loss: 0.4884 - val_accuracy: 0.8226
# Epoch 3/10
# 179/179 [==============================] - 1684s 9s/step - loss: 0.4162 - accuracy: 0.8202 - val_loss: 0.7859 - val_accuracy: 0.6942
# Epoch 4/10
# 179/179 [==============================] - 1662s 9s/step - loss: 0.4093 - accuracy: 0.8323 - val_loss: 14.9540 - val_accuracy: 0.5726
# Epoch 5/10
# 179/179 [==============================] - 1711s 10s/step - loss: 0.3660 - accuracy: 0.8404 - val_loss: 0.3918 - val_accuracy: 0.8305
# Epoch 6/10
# 179/179 [==============================] - 1678s 9s/step - loss: 0.3651 - accuracy: 0.8363 - val_loss: 0.3857 - val_accuracy: 0.8242
# Epoch 7/10
# 179/179 [==============================] - 1756s 10s/step - loss: 0.3514 - accuracy: 0.8491 - val_loss: 0.3682 - val_accuracy: 0.8400
# Epoch 8/10
# 179/179 [==============================] - 2446s 14s/step - loss: 0.3527 - accuracy: 0.8488 - val_loss: 0.3618 - val_accuracy: 0.8463
# Epoch 9/10
# 179/179 [==============================] - 3096s 17s/step - loss: 0.3413 - accuracy: 0.8502 - val_loss: 0.4191 - val_accuracy: 0.8226
# Epoch 10/10
# 179/179 [==============================] - 3183s 18s/step - loss: 0.3468 - accuracy: 0.8577 - val_loss: 0.5355 - val_accuracy: 0.7953

# %%
model.save("model_resnet50.h5")

# %%
pd.DataFrame(history.history)[['accuracy', 'val_accuracy']].plot()
plt.title("Accuracy")
plt.show()

pd.DataFrame(history.history)[['loss','val_loss']].plot()
plt.title("Loss")
plt.show()

# %%
results= model.evaluate(test_gen, verbose=0)
print("\tTest Loss: {:5f}".format(results[0]))
print("test Accuracy: {:2f}%".format(results[1]*100))
# Out:
# 	Test Loss: 0.535462
# test Accuracy: 79.526317%

# %%
pred= model.predict(test_gen)
pred=np.argmax(pred,axis=1)

labels=(train_gen.class_indices)
labels=dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]
# Out:
# 60/60 [==============================] - 294s 5s/step

# %%
y_test=list(test.Label)
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.81      0.76      0.78       936
#    malignant       0.78      0.83      0.80       964
#
#     accuracy                           0.80      1900
#    macro avg       0.80      0.79      0.79      1900
# weighted avg       0.80      0.80      0.79      1900

# %%
#confusion matrix
confusion_matrix = metrics.confusion_matrix(y_test, pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])
cm_display.plot()
plt.show()

# %%
#apply preprocessing: normalizing, reshaping, augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)
test_datagen = ImageDataGenerator(
    rescale=1./255
)

# %%
train_gen = train_datagen.flow_from_dataframe(
    dataframe=train,
    x_col='Filepath',
    y_col='Label',
    target_size=(224,224),
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42
)
valid_gen = train_datagen.flow_from_dataframe(
    dataframe=test,
    x_col='Filepath',
    y_col='Label',
    target_size=(224,224),
    class_mode='categorical',
    batch_size=32,
    shuffle=False,
    seed=42
)
test_gen = test_datagen.flow_from_dataframe(
    dataframe=test,
    x_col='Filepath',
    y_col='Label',
    target_size=(224,224),
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 5700 validated image filenames belonging to 2 classes.
# Found 1900 validated image filenames belonging to 2 classes.
# Found 1900 validated image filenames belonging to 2 classes.

# %%
pretrained_model = MobileNetV2(weights='imagenet', 
                      include_top=False,
                     input_shape=(224,224,3)
                     )

# %%
pretrained_model.trainable = False

#add a global spatial average pooling layer
x = pretrained_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(200,activation='elu')(x)
x = Dropout(0.4)(x)
x = Dense(170,activation='elu')(x)
outputs = Dense(2,activation='softmax')(x)

model = Model(inputs=pretrained_model.input, outputs=outputs)

# %%
model.compile(optimizer='adam', 
              loss='binary_crossentropy',
              metrics=['accuracy']
             )

# %%
history = model.fit(train_gen,
                    epochs=10,
                    validation_data=valid_gen)
# Out:
# Epoch 1/10
# 179/179 [==============================] - 498s 3s/step - loss: 0.4732 - accuracy: 0.7839 - val_loss: 0.4204 - val_accuracy: 0.8132
# Epoch 2/10
# 179/179 [==============================] - 488s 3s/step - loss: 0.3907 - accuracy: 0.8298 - val_loss: 0.3807 - val_accuracy: 0.8347
# Epoch 3/10
# 179/179 [==============================] - 485s 3s/step - loss: 0.3703 - accuracy: 0.8375 - val_loss: 0.4081 - val_accuracy: 0.8174
# Epoch 4/10
# 179/179 [==============================] - 477s 3s/step - loss: 0.3616 - accuracy: 0.8402 - val_loss: 0.3980 - val_accuracy: 0.8200
# Epoch 5/10
# 179/179 [==============================] - 467s 3s/step - loss: 0.3560 - accuracy: 0.8409 - val_loss: 0.3615 - val_accuracy: 0.8363
# Epoch 6/10
# 179/179 [==============================] - 474s 3s/step - loss: 0.3408 - accuracy: 0.8521 - val_loss: 0.3614 - val_accuracy: 0.8353
# Epoch 7/10
# 179/179 [==============================] - 465s 3s/step - loss: 0.3358 - accuracy: 0.8523 - val_loss: 0.3642 - val_accuracy: 0.8363
# Epoch 8/10
# 179/179 [==============================] - 496s 3s/step - loss: 0.3285 - accuracy: 0.8604 - val_loss: 0.3755 - val_accuracy: 0.8395
# Epoch 9/10
# 179/179 [==============================] - 474s 3s/step - loss: 0.3302 - accuracy: 0.8549 - val_loss: 0.3672 - val_accuracy: 0.8447
# Epoch 10/10
# 179/179 [==============================] - 485s 3s/step - loss: 0.3216 - accuracy: 0.8642 - val_loss: 0.3751 - val_accuracy: 0.8311

# %%
model.save("model_mobilenetV2.h5")

# %%
pd.DataFrame(history.history)[['accuracy', 'val_accuracy']].plot()
plt.title("Accuracy")
plt.show()

pd.DataFrame(history.history)[['loss','val_loss']].plot()
plt.title("Loss")
plt.show()

# %%
results = model.evaluate(test_gen, verbose=0)

print("\tTest Loss: {:5f}".format(results[0]))
print("test Accuracy: {:2f}%".format(results[1]*100))
# Out:
# 	Test Loss: 0.414762
# test Accuracy: 81.999999%

# %%
pred= model.predict(test_gen)
pred=np.argmax(pred,axis=1)

labels=(train_gen.class_indices)
labels=dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]
# Out:
# 60/60 [==============================] - 100s 2s/step

# %%
y_test=list(test.Label)
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.76      0.93      0.84       947
#    malignant       0.91      0.71      0.80       953
#
#     accuracy                           0.82      1900
#    macro avg       0.84      0.82      0.82      1900
# weighted avg       0.84      0.82      0.82      1900

# %%
#confusion matrix
confusion_matrix = metrics.confusion_matrix(y_test, pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])
cm_display.plot()
plt.show()
